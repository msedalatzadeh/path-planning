# %%
import matplotlib.pyplot as plt
# !pip install Image
import Image as img
import numpy as np

im = img.open('boat.png')
height = im.size[1]

# We need a float array between 0-1, rather than
# a uint8 array between 0-255
im = np.array(im).astype(np.float) / 255

fig = plt.figure()

plt.plot(np.arange(10), 4 * np.arange(10))

# With newer (1.0) versions of matplotlib, you can 
# use the "zorder" kwarg to make the image overlay
# the plot, rather than hide behind it... (e.g. zorder=10)
fig.figimage(im, 0, fig.bbox.ymax - height)

# (Saving with the same dpi as the screen default to
#  avoid displacing the logo image)
fig.savefig('test.png', dpi=80)

plt.show()
# Out:
# ...
# You are using pip version 10.0.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-ff31bfbfdfbe> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 get_ipython().system('pip install Image')
# ----> 3 import Image as img
#       4 import numpy as np
#       5
#
# ModuleNotFoundError: No module named 'Image'

# %%
import matplotlib.pyplot as plt
from matplotlib.cbook import get_sample_data
import scipy.ndimage as ndimage

fig, ax = plt.subplots()
ax.plot(range(10))

newax = fig.add_axes([0, 0, 1, 1])

im = plt.imread('boat.png')
img_boat = ndimage.rotate(im, 10)
img_boat = ndimage.shift(img_boat, [0,0,0])


# Place the image in the upper-right corner of the figure
#--------------------------------------------------------
# We're specifying the position and size in _figure_ coordinates, so the image
# will shrink/grow as the figure is resized. Remove "zorder=-1" to place the
# image in front of the axes.
newax.imshow(img_boat)
newax.axis('off')

plt.show()


from matplotlib.offsetbox import OffsetImage, AnnotationBbox

def getImage(path):
    return OffsetImage(plt.imread(path))

ab = AnnotationBbox(getImage('boat2.png'), (1, 1), frameon=False)
ax.add_artist(ab)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import matplotlib.pyplot as plt
from matplotlib.cbook import get_sample_data
import scipy.ndimage as ndimage
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

fig, ax = plt.subplots()
ax.plot(range(10))

def rotate_image(path, degree):
    img = plt.imread(path)
    img = ndimage.rotate(img, degree)
    return OffsetImage(img, zoom=0.2)

ab = AnnotationBbox(rotate_image('boat2.png', 10), (5, 5), frameon=False)
ax.add_artist(ab)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
